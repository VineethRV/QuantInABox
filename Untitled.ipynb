# %%
import praw
import os

# %%
reddit = praw.Reddit(
    client_id="v7jkdZIELuo2oNSQqkLGNQ",
    client_secret="y1t14fhgLXvpNJk0xAee1rWYMdnufQ",
    user_agent="python:my_reddit_app:v1.0 (by /u/Practical_Vast_6510)",
    username="Practical_Vast_6510",
    password="PEEINGredditfails@5"
)
print(reddit)

# %%
subreddit = reddit.subreddit("technology")  # Change to any subreddit
for post in subreddit.search("AI", limit=5):
    print(f"Title: {post.title}\nURL: {post.url}\n")
# Out:
# ---------------------------------------------------------------------------
# OAuthException                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 subreddit = reddit.subreddit("technology")  # Change to any subreddit
# ----> 2 for post in subreddit.search("AI", limit=5):
#       3     print(f"Title: {post.title}\nURL: {post.url}\n")
#
# File ~/.local/lib/python3.10/site-packages/praw/models/listing/generator.py:66, in ListingGenerator.__next__(self)
#      63     raise StopIteration
#      65 if self._listing is None or self._list_index >= len(self._listing):
# ---> 66     self._next_batch()
#      68 self._list_index += 1
#      69 self.yielded += 1
#
# File ~/.local/lib/python3.10/site-packages/praw/models/listing/generator.py:90, in ListingGenerator._next_batch(self)
#      87 if self._exhausted:
#      88     raise StopIteration
# ---> 90 self._listing = self._reddit.get(self.url, params=self.params)
# ...
